# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsanyonee/Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall = 11.5
kit = 18.0
liv = 20.0
bed = 10.7
bath = 10
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.5, 18.0, 20.0, 10.7, 10]

# %%
areas = [hall, kit, "living room", liv, bed, "bedroom", bath]
print(areas)
# Out:
# [11.5, 18.0, 'living room', 20.0, 10.7, 'bedroom', 10]

# %%
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.5], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %%
areas = ["hallway", 11.5, "kitchen", 18.0, "living room", 20.0, "bedroom", ]
