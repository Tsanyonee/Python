# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsanyonee/Python/blob/main/v%C3%B2ng_l%E1%BA%B7p_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

n = int(input("nhập một số nguyên dương:"))
print(n)
a = 0
for b in range(n + 1):
  a += b
print(f"Tổng của các số từ 0 đến {n} là: {a}")
# Out:
# nhập một số nguyên dương:5
# 5
# Tổng của các số từ 0 đến 5 là: 15
